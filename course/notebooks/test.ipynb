# %% [markdown]
# # This is a headline
# ## This is a subheadline
# ### This is a subsubheadline
#
# - This is a bullet point
# - This is another bullet point
#
# 1. This is a numbered list
# 2. This is another numbered list
#
# This is a paragraph. You can write text in here.
#
# This is a LaTeX equation: $y = x^2$
#
# This a LaTeX equation in display mode:
# $$
# \begin{align*}
# y &= x^2 \\
# y &= x^3 \\
# \end{align*}
# $$
#
# This is a code block:
# ```python
# print("Hello, World!")
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
fig = plt.figure(figsize=(3, 3))
plt.plot(x, y)
plt.show()
